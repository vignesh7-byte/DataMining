# %% [markdown]
# <a href="https://colab.research.google.com/github/vignesh7-byte/DataMining/blob/main/ADM_LAB_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = "/content/titanic (2).csv"
df = pd.read_csv('/content/titanic (2).csv')

# %%
print("Dataset Shape:", df.shape)
print("Column Info:")
df.info()
print("Summary Statistics:")
print(df.describe())
# Out:
# Dataset Shape: (891, 12)
# Column Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# Summary Statistics:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...

# %%
missing_values = df.isnull().sum()
print("Missing Values:")
print(missing_values)
# Out:
# Missing Values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = df.dropna()

# %%
numeric_df = df.select_dtypes(include=[np.number])

# %%
numeric_df = numeric_df.loc[:, numeric_df.nunique() > 1]

# %%
correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Feature Correlation Matrix")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=numeric_df)
plt.title("Box Plot for Detecting Outliers")
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(numeric_df)
plt.show()

# %%
print("EDA Completed Successfully")
# Out:
# EDA Completed Successfully
